# %%
import json
from folium.plugins import MarkerCluster
import folium

import requests
from PIL import Image
from io import BytesIO

LOGO_HEIGHT = 80

# Function to get the dimensions of an image from URL
def get_image_dimensions_from_url(image_url):
    try:
        response = requests.get(image_url)
        response.raise_for_status()  # Raise an exception for HTTP errors
        img = Image.open(BytesIO(response.content))
        return img.size
    except Exception as e:
        print(f"Error fetching or processing image: {e}")
        return None


# Load GeoJSON data
with open('map.json') as f:
    data = json.load(f)

# Create a map centered on a specific location
m = folium.Map(location=[42, -71], zoom_start=5, tiles='cartodbpositron')
marker_cluster = MarkerCluster().add_to(m)
# Iterate over features in the GeoJSON data
for feature in data['features']:
    name = feature['properties']['name']
    url = feature['properties']['url']
    if url == "URL_PLACEHOLDER":
        url = "https://upload.wikimedia.org/wikipedia/commons/9/92/LOGO_CEA_ORIGINAL.svg"
    coordinates = feature['geometry']['coordinates']
    
    # Get the dimensions of the image from URL
    image_dimensions = get_image_dimensions_from_url(url)
    if image_dimensions:
        height_to_width_ratio = image_dimensions[1] / image_dimensions[0]
        image_dimensions = (int(LOGO_HEIGHT / height_to_width_ratio), LOGO_HEIGHT)
    else:
        image_dimensions = (LOGO_HEIGHT, LOGO_HEIGHT)
    # Create a marker with a custom icon and popup
    if coordinates != [0, 0]:
        icon = folium.CustomIcon(url, icon_size=image_dimensions)
        folium.Marker(
            location=[coordinates[1], coordinates[0]],
            icon=icon,
        ).add_to(marker_cluster)
    else:
        print("no coordinates for", name)
m.save('map.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2782644de9f2f807af36d14fb084fe4a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2782644de9f2f807af36d14fb084fe4a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2782644de9f2f807af36d14fb084fe4a = L.map(
#                 &quot;map_2782644de9f2f807af36d14fb084fe4a&quot;,
#                 {
#                     center: [42.0, -71.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0e14ce9d9292319e5d1746e2749855d0 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0e14ce9d9292319e5d1746e2749855d0.addTo(map_2782644de9f2f807af36d14fb084fe4a);
#
#
#             var marker_cluster_90036e1f2351c04aa7e0dc4d8d6aaa8f = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_3a60a3c1982064c9c68204ff3ab0e3ad = L.marker(
#                 [43.7254, 5.7843],
#                 {}
#             ).addTo(marker_cluster_90036e1f2351c04aa7e0dc4d8d6aaa8f);
#
#
#         var custom_icon_a4a8e76fd50751055b730615039acdc1 = L.icon({&quot;iconSize&quot;: [80, 80], &quot;iconUrl&quot;: &quot;https://upload.wikimedia.org/wikipedia/commons/thumb/9/92/LOGO_CEA_ORIGINAL.svg/768px-LOGO_CEA_ORIGINAL.svg.png&quot;});
#         marker_3a60a3c1982064c9c68204ff3ab0e3ad.setIcon(custom_icon_a4a8e76fd50751055b730615039acdc1);
#
#
#             var marker_bb629e3aad0f89f7aa2c208db579bef5 = L.marker(
#                 [48.9583, 2.3458],
#                 {}
#             ).addTo(marker_cluster_90036e1f2351c04aa7e0dc4d8d6aaa8f);
#
#
#         var custom_icon_88802a4ee235d6cf16baf348499d786c = L.icon({&quot;iconSize&quot;: [80, 80], &quot;iconUrl&quot;: &quot;https://upload.wikimedia.org/wikipedia/en/thumb/2/2c/CNRS.svg/316px-CNRS.svg.png&quot;});
#         marker_bb629e3aad0f89f7aa2c208db579bef5.setIcon(custom_icon_88802a4ee235d6cf16baf348499d786c);
#
#
#             var marker_c2b88cc4d7d0d50994c87ce85d230697 = L.marker(
#                 [42.3601, -71.0921],
#                 {}
#             ).addTo(marker_cluster_90036e1f2351c04aa7e0dc4d8d6aaa8f);
#
#
#         var custom_icon_87f943ec3c75406b7b933833c4b6c4dc = L.icon({&quot;iconSize&quot;: [154, 80], &quot;iconUrl&quot;: &quot;https://upload.wikimedia.org/wikipedia/commons/thumb/0/0c/MIT_logo.svg/321px-MIT_logo.svg.png&quot;});
#         marker_c2b88cc4d7d0d50994c87ce85d230697.setIcon(custom_icon_87f943ec3c75406b7b933833c4b6c4dc);
#
#
#             var marker_45191b1364bdeb6680cb4bc7845d8a5b = L.marker(
#                 [40.35006468849364, -74.6596903],
#                 {}
#             ).addTo(marker_cluster_90036e1f2351c04aa7e0dc4d8d6aaa8f);
#
#
#         var custom_icon_9aeee2012bc4d863db3133da661aa239 = L.icon({&quot;iconSize&quot;: [152, 80], &quot;iconUrl&quot;: &quot;https://media.licdn.com/dms/image/sync/D4E27AQEtSPdhh29Xiw/articleshare-shrink_800/0/1711995007077?e=1714071600\u0026v=beta\u0026t=l2mnifsctT8XWseYQSfPIyzRpwsAYVgq5j-FOWejeyY&quot;});
#         marker_45191b1364bdeb6680cb4bc7845d8a5b.setIcon(custom_icon_9aeee2012bc4d863db3133da661aa239);
#
#
#             var marker_dc307614c2b99fba6238f1e709ccd7d3 = L.marker(
#                 [42.5406, -71.6152],
#                 {}
#             ).addTo(marker_cluster_90036e1f2351c04aa7e0dc4d8d6aaa8f);
#
#
#         var custom_icon_882083ce9dbc5f13076189248fd9a24e = L.icon({&quot;iconSize&quot;: [78, 80], &quot;iconUrl&quot;: &quot;https://api-kla-prod.2ambh.com/v1/images/10348/thumb/w950&quot;});
#         marker_dc307614c2b99fba6238f1e709ccd7d3.setIcon(custom_icon_882083ce9dbc5f13076189248fd9a24e);
#
#
#             var marker_a7717147ea6f6765ed8583faa6889163 = L.marker(
#                 [43.0761, -89.4012],
#                 {}
#             ).addTo(marker_cluster_90036e1f2351c04aa7e0dc4d8d6aaa8f);
#
#
#         var custom_icon_ff89fe85024a2fdc30c0233e65fedf9f = L.icon({&quot;iconSize&quot;: [120, 80], &quot;iconUrl&quot;: &quot;https://brand.wisc.edu/content/uploads/2023/09/vert-w-crest-logo-web-digital-color.png&quot;});
#         marker_a7717147ea6f6765ed8583faa6889163.setIcon(custom_icon_ff89fe85024a2fdc30c0233e65fedf9f);
#
#
#             var marker_735885610f0eaf0583c93b5d4ae5f4d6 = L.marker(
#                 [37.774
